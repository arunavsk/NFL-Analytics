# %%
import pandas as pd

# %%
injury_record = pd.read_csv('./data/InjuryRecord.csv')

# %%
injury_record.head(20)
# Out:
#     PlayerKey    GameID      PlayKey BodyPart    Surface  DM_M1  DM_M7  \
# 0       39873   39873-4   39873-4-32     Knee  Synthetic      1      1
# 1       46074   46074-7   46074-7-26     Knee    Natural      1      1
# 2       36557   36557-1   36557-1-70    Ankle  Synthetic      1      1
# 3       46646   46646-3   46646-3-30    Ankle    Natural      1      0
# 4       43532   43532-5   43532-5-69    Ankle  Synthetic      1      1
# 5       41145   41145-2   41145-2-60     Knee    Natural      1      0
# 6       46014  46014-10  46014-10-22    Ankle  Synthetic      1      1
# 7       44860   44860-5   44860-5-52     Knee    Natural      1      1
# 8       44806   44806-7   44806-7-61     Knee  Synthetic      1      0
# 9       45962   45962-8   45962-8-40    Ankle  Synthetic      1      1
# 10      46331   46331-4   46331-4-44    Ankle  Synthetic      1      1
# 11      36621  36621-13  36621-13-58     Foot    Natural      1      1
# 12      44492   44492-3   44492-3-23    Ankle    Natural      1      1
# 13      43505   43505-2   43505-2-49     Foot    Natural      1      1
# 14      41094   41094-1   41094-1-55     Knee    Natural      1      1
# 15      40474   40474-1    40474-1-8     Knee  Synthetic      1      0
# 16      39656   39656-2   39656-2-38     Knee  Synthetic      1      1
# 17      46587   46587-2   46587-2-13     Knee  Synthetic      1      1
# 18      46119   46119-3   46119-3-16     Knee    Natural      1      1
# 19      38364   38364-5   38364-5-23     Foot  Synthetic      1      1
#
#     DM_M28  DM_M42
# 0        1       1
# 1        0       0
# 2        1       1
# 3        0       0
# 4        1       1
# 5        0       0
# 6        1       1
# 7        0       0
# 8        0       0
# 9        0       0
# 10       1       1
# 11       1       1
# 12       1       1
# 13       1       1
# 14       1       1
# 15       0       0
# 16       0       0
# 17       1       1
# 18       0       0
# 19       1       1

# %%
injury_record.shape
# Out:
# (105, 9)

# %%
injury_record['PlayerKey'].nunique()
# Out:
# 100

# %%
injury_record.groupby('Surface')['PlayerKey'].count()
# Out:
# Surface
# Natural      48
# Synthetic    57
# Name: PlayerKey, dtype: int64

# %%
injury_record['BodyPart'].unique()
# Out:
# array(['Knee', 'Ankle', 'Foot', 'Toes', 'Heel'], dtype=object)

# %%
injury_record.groupby('BodyPart')['PlayerKey'].count()
# Out:
# BodyPart
# Ankle    42
# Foot      7
# Heel      1
# Knee     48
# Toes      7
# Name: PlayerKey, dtype: int64

# %%
injury_record[injury_record['BodyPart'].isin(['Ankle','Knee'])].groupby(['BodyPart', 'Surface'])['PlayerKey'].count()
# Out:
# BodyPart  Surface
# Ankle     Natural      17
#           Synthetic    25
# Knee      Natural      24
#           Synthetic    24
# Name: PlayerKey, dtype: int64

# %%
injury_record['severity'] = injury_record['DM_M1'] + injury_record['DM_M7'] + injury_record['DM_M28'] + injury_record['DM_M42']

# %%
injury_record.groupby('severity')['PlayerKey'].count()
# Out:
# severity
# 1    29
# 2    39
# 3     8
# 4    29
# Name: PlayerKey, dtype: int64

# %%
injury_record.groupby(['Surface','BodyPart','severity'])['PlayerKey'].count().reset_index()
# Out:
#       Surface BodyPart  severity  PlayerKey
# 0     Natural    Ankle         1          8
# 1     Natural    Ankle         2          6
# 2     Natural    Ankle         4          3
# 3     Natural     Foot         3          1
# 4     Natural     Foot         4          4
# 5     Natural     Heel         2          1
# 6     Natural     Knee         1          5
# 7     Natural     Knee         2         12
# 8     Natural     Knee         3          1
# 9     Natural     Knee         4          6
# 10    Natural     Toes         2          1
# 11  Synthetic    Ankle         1          8
# 12  Synthetic    Ankle         2          7
# 13  Synthetic    Ankle         3          2
# 14  Synthetic    Ankle         4          8
# 15  Synthetic     Foot         3          1
# 16  Synthetic     Foot         4          1
# 17  Synthetic     Knee         1          6
# 18  Synthetic     Knee         2          9
# 19  Synthetic     Knee         3          2
# 20  Synthetic     Knee         4          7
# 21  Synthetic     Toes         1          2
# 22  Synthetic     Toes         2          3
# 23  Synthetic     Toes         3          1
